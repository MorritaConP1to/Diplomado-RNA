# %% [raw]
# ## Regresion Linean: Coste de incidente de Seguridad
# En este ejercicio se explicaran los fundamentos basicos de la regresion lineal aplicada a un caso de uso sencillo relacionado con la ciberseguridad

# %% [markdown]
# ## Enunciado del ejercicio
# Este ejercicio consiste en predecir el costo de un incidente de seguridad en vase al numero que se han visto afectados. Es congunto de datos es generado de manera aleatoria.

# %% [markdown]
# # Realizar importanciones

# %% [markdown]
# ## Instalaciones de librerias externas
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-3.0.1-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 10.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 10.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.3 MB/s  0:00:01
# Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.4 MB 11.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.4 MB 11.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.4 MB 11.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.4 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.4 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 10.5 MB/s  0:00:01
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, six, numpy, python-dateutil, pandas
#
#    ---------------------------------------- 0/5 [tzdata]
#    ---------------------------------------- 0/5 [tzdata]
#    -------- ------------------------------- 1/5 [six]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ------------------------ --------------- 3/5 [python-dateutil]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    ---------------------------------------- 5/5 [pandas]
#
# Successfully installed numpy-2.4.3 pandas-3.0.1 python-dateutil-2.9.0.post0 six-1.17.0 tzdata-2025.3
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\darck\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.4.3)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\darck\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.4.3)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darck\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\darck\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.3 MB 10.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.3 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 10.1 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------------------- ---- 2.1/2.3 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 10.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 11.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 10.7 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, packaging, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [packaging]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ------------------------------ --------- 6/8 [contourpy]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 packaging-26.0 pillow-12.1.1 pyparsing-3.3.2
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\darck\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (2.4.3)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 10.3 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.1 MB 10.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.2 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/37.3 MB 11.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/37.3 MB 11.0 MB/s eta 0:00:03
#    ------- -------------------------------- 6.6/37.3 MB 11.0 MB/s eta 0:00:03
#    --------- ------------------------------ 8.7/37.3 MB 11.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.0/37.3 MB 11.0 MB/s eta 0:00:03
#    -------------- ------------------------- 13.4/37.3 MB 11.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.5/37.3 MB 11.0 MB/s eta 0:00:02
#    ------------------ --------------------- 17.6/37.3 MB 11.0 MB/s eta 0:00:02
#    --------------------- ------------------ 19.9/37.3 MB 11.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.0/37.3 MB 11.0 MB/s eta 0:00:02
#    -------------------------- ------------- 24.4/37.3 MB 11.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.7/37.3 MB 11.0 MB/s eta 0:00:01
#    ------------------------------ --------- 28.8/37.3 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 31.2/37.3 MB 11.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.3/37.3 MB 11.0 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/37.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 10.7 MB/s  0:00:03
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Darck\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Generacion del conjunto de datos

# %%
import numpy as np

x = 2 * np.random.rand(100,1)
y = 4 + 3 * x + np.random.rand(100,1)
print("La longitud del conjunto de datos:",len(x))
# Out:
# La longitud del conjunto de datos: 100

# %% [markdown]
# ### Visualizacion del conjunto de datos

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y,"b.")
plt.show()

# %%
plt.plot(x,y,"b.")
plt.xlabel("Equipos afectados (u*1_000)")
plt.ylabel("Costo del incididente (u*1_000)")
plt.show()

# %% [markdown]
# ### Modificacion del conjunto de datos

# %%
import pandas as pd

# %% [markdown]
# convertimos los datos a su valor real, en lugar de usar factores de conversion

# %%
data = {'n_equipos_afectados': x.flatten(),'costo': y.flatten()}
df = pd.DataFrame(data)
df.head(10)
# Out:
#    n_equipos_afectados      costo
# 0             0.113468   5.328910
# 1             1.959789  10.383367
# 2             1.930710  10.293687
# 3             1.480113   8.681748
# 4             0.576123   6.651132
# 5             1.214324   7.903600
# 6             1.543080   8.925469
# 7             1.357287   8.235195
# 8             1.016626   7.695517
# 9             1.227518   8.278258

# %% [markdown]
# # Escalado del numero de equipos afectados a un valor mas real

# %%
df['n_equipos_afectados']= df['n_equipos_afectados'] * 1_000
df['n_equipos_afectados']= df['n_equipos_afectados'].astype('int')

# %% [markdown]
# # Escalado del costo a un valor mas real

# %%
df['costo']= df['costo'] * 10_000
df['costo']= df['costo'].astype('int')

df.head(10)
# Out:
#    n_equipos_afectados   costo
# 0                  113   53289
# 1                 1959  103833
# 2                 1930  102936
# 3                 1480   86817
# 4                  576   66511
# 5                 1214   79035
# 6                 1543   89254
# 7                 1357   82351
# 8                 1016   76955
# 9                 1227   82782

# %% [markdown]
# # Representacion grafica del conjunto de datos

# %%
plt.plot(df['n_equipos_afectados'],df['costo'], "b.")
plt.xlabel("Equipos afectados")
plt.ylabel("Costo del incididente")
plt.show()

# %% [markdown]
# # Construccion del modelo

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Darck\.conda\envs\Diplomado-RNA\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Darck\.conda\envs\Diplomado-RNA\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Darck\.conda\envs\Diplomado-RNA\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Darck\.conda\envs\Diplomado-RNA\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Darck\.conda\envs\Diplomado-RNA\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Carga de modelo y ajuste de la funcion Hipotesis

# %%
lin_rege = LinearRegression()
lin_rege.fit(df['n_equipos_afectados'].values.reshape(-1,1) ,df['costo'].values)
# Out:
# LinearRegression()

# %% [markdown]
# Muestra el valor que se le asigno al parametro Theta0 (Lugar donde corta el modelo con el eje "Y"

# %%
lin_rege.intercept_
# Out:
# np.float64(45441.24856331597)

# %% [markdown]
# muestra el Vaor que se le asigno al parametro Theta1 (pendiente que tendra el modelo de regresion lineal)

# %%
lin_rege.coef_
# Out:
# array([29.57990926])

# %% [markdown]
# ### Prediccion para el valor minimo y maximo del conjunto de datos de entrenaiento

# %%
x_min_max = np.array([[df['n_equipos_afectados'].min()],[df['n_equipos_afectados'].max()]])
y_train_pred = lin_rege.predict(x_min_max)

# %% [markdown]
# # Representacion Grafica de la funcion de Hipotesis Generada

# %%
plt.plot(x_min_max,y_train_pred,"g-")
plt.plot(df['n_equipos_afectados'],df['costo'], "b.")
plt.xlabel("Equipos afectados")
plt.ylabel("Costo del incididente")
plt.show()

# %% [markdown]
# ### Prediccion de nuevos ejemplos

# %%
x_new = np.array([760]) # 760 equipos afectados

# %% [markdown]
# Prediccion del costo que tendria este incidente

# %%
costo = lin_rege.predict(x_new)
print("El costo del incididente seria: ",costo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 costo = lin_rege.predict(x_new)
#       2 print("El costo del incididente seria: ",costo)
#
# File ~\.conda\envs\Diplomado-RNA\Lib\site-packages\sklearn\linear_model\_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)    309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File ~\.conda\envs\Diplomado-RNA\Lib\site-packages\sklearn\linear_model\_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File ~\.conda\envs\Diplomado-RNA\Lib\site-packages\sklearn\utils\validation.py:2902, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2900         out = X, y
#    2901 elif not no_val_X and no_val_y:
# -> 2902     out = check_array(X, input_name="X", **check_params)
#    2903 elif no_val_X and not no_val_y:
#    2904     out = _check_y(y, **check_params)
#
# File ~\.conda\envs\Diplomado-RNA\Lib\site-packages\sklearn\utils\validation.py:1060, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1053         else:
#    1054             msg = (
#    1055                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1056                 "Reshape your data either using array.reshape(-1, 1) if "
#    1057                 "your data has a single feature or array.reshape(1, -1) "
#    1058                 "if it contains a single sample."
#    1059             )
# -> 1060         raise ValueError(msg)
#    1062 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1063     raise ValueError(
#    1064         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1065         "Convert your data to numeric values explicitly instead."
#    1066     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[760].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
plt.plot(x_min_max,y_train_pred,"g-")
plt.plot(df['n_equipos_afectados'],df['costo'], "b.")
plt.plot(x_new,costo,"rx")
plt.xlabel("Equipos afectados")
plt.ylabel("Costo del incididente")
plt.show()
