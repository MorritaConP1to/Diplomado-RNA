# %% [markdown]
# # 🤖 Módulo 1 — Introducción a la Inteligencia Artificial
# **Diplomado Superior en Redes Neuronales Artificiales y Deep Learning**
# Machote de práctica — Diana Blanco
#
#
# > 🔨 **¿Para qué sirve este archivo?** → Template de trabajo. Copia y adapta las celdas  \> marcadas con #MACHOTE a tus ejercicios. Las celdas #TODO son ejercicios para que  \> practiques. Puedes ejecutar todo el notebook de principio a fin.---
# ### Temario cubierto:
# 1. Conceptos Fundamentales — tipos de aprendizaje, ramas de la IA, conceptos clave
# 2. Historia de las RNA — hitos desde 1943 hasta la actualidad
# 3. Repaso de Vectores — operaciones, producto punto, magnitud
# 4. Repaso de Matrices — suma, producto, transpuesta, inversa
# 5. Derivadas — reglas básicas y regla de la cadena
# 6. Funciones — visualización de funciones elementales
# 7. Ruta del Diplomado — mapa de los 5 módulos
# 8. Ejercicios Integradores — teoría + matemáticas
#
# > 📌 **Instrucciones:** Celdas marcadas con `# TODO` son para completar.
# > Celdas marcadas con `# MACHOTE` son reutilizables en tus proyectos.

# %% [markdown]
# ---
# ## ⚙️ 0. Setup — Cargar librería del módulo

# %%
# MACHOTE — Cargar funciones de libreria_modulo1
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join('..')))
from libreria_modulo1 import *
print('✅ libreria_modulo1 cargada')

# %%
# MACHOTE — Detectar plataforma y configurar reproducibilidad
detectar_plataforma()
configurar_reproducibilidad(42)

# %% [markdown]
# ---
# ## 🧠 1. Conceptos Fundamentales

# %%
# MACHOTE — Tipos de aprendizaje
tipos_aprendizaje()

# %%
# MACHOTE — Ramas de la IA
ramas_ia()

# %%
# MACHOTE — Conceptos clave
for c in ['ia', 'ml', 'dl', 'red_neuronal', 'backpropagation', 'gradiente']:
    concepto_clave(c)
    print()

# %%
# TODO — Consulta los conceptos 'overfitting' y 'underfitting'
# concepto_clave('overfitting')
# concepto_clave('underfitting')

# %% [markdown]
# ---
# ## 📜 2. Historia de las Redes Neuronales

# %%
# MACHOTE — Línea del tiempo de las RNA
hitos_rna()

# %%
# TODO — ¿Qué periodo consideras más importante y por qué?
# Escribe tu reflexión como comentario
# 
# Tu respuesta:

# %% [markdown]
# ---
# ## 📐 3. Repaso de Vectores

# %%
# MACHOTE — Operaciones básicas con vectores
vectores_basicos()

# %%
# TODO — Crea dos vectores 3D manualmente y calcula:
# 1. Producto punto
# 2. Ángulo entre ellos
# 3. Proyección de v1 sobre v2

v1 = np.array([2, -1, 3])
v2 = np.array([0, 4, 1])

# producto_punto =
# angulo_cos =
# proyeccion =

# %% [markdown]
# ---
# ## 📊 4. Repaso de Matrices

# %%
# MACHOTE — Operaciones básicas con matrices
matrices_basicas()

# %%
# TODO — Define una matriz 2x2 C = [[2, -1], [0, 3]] y calcula:
# 1. C^2 (C @ C)
# 2. Traza de C (suma diagonal)
# 3. ¿Es C invertible? Si sí, muéstra su inversa

# C = np.array([[... , ...], [... , ...]])
# C_cuadrado =
# traza =
# C_inversa =

# %% [markdown]
# ---
# ## 📈 5. Derivadas

# %%
# MACHOTE — Reglas de derivación
derivada_simbolica()

# %%
# TODO — Aplica la regla de la cadena paso a paso:
# Sea f(x) = sigmoide(2x + 1)  donde sigmoide(z) = 1 / (1 + e^(-z))
# Encuentra f'(x) usando lápiz y papel, luego verifica aproximando numéricamente

def sigmoide(z):
    return 1 / (1 + np.exp(-z))

def f(x):
    return sigmoide(2*x + 1)

# Derivada numérica (aproximación centrada)
h = 1e-6
x0 = 0.5
# f_prima_num = (f(x0 + h) - f(x0 - h)) / (2*h)
# print(f'f\'({x0}) ≈ {f_prima_num:.6f}')

# %% [markdown]
# ---
# ## 📉 6. Funciones

# %%
# MACHOTE — Visualización de funciones elementales
graficar_funciones()

# %%
# TODO — Grafica la función sigmoide y su derivada
# Usa np.linspace(-8, 8, 100)
# x = ...
# s = sigmoide(x)
# ds = s * (1 - s)
# Crea una figura con dos subplots

# %% [markdown]
# ---
# ## 🗺️ 7. Ruta del Diplomado

# %%
# MACHOTE — Mapa completo del diplomado
ruta_diplomado()

# %%
# TODO — ¿Qué módulo te llama más la atención y por qué?
# Escribe tu reflexión como comentario
# 
# Tu respuesta:

# %% [markdown]
# ---
# ## 🏋️ 8. Ejercicios Integradores

# %%
# TODO — Clasifica los siguientes problemas por tipo de aprendizaje:
# a) Predecir el precio de una casa según sus características
# b) Agrupar clientes por patrones de compra
# c) Un robot aprendiendo a caminar por ensayo y error
# d) Detectar fraudes en transacciones bancarias
#
# Escribe tu respuesta:
# a) 
# b) 
# c) 
# d)

# %%
# TODO — Multiplicación de matrices en el contexto de RNA
# Una capa fully-connected recibe un vector de entrada x (4,)
# y tiene una matriz de pesos W de forma (3, 4) y sesgo b (3,)
# Calcula: z = W @ x + b

x = np.array([0.5, -0.3, 0.8, 0.1])
W = np.array([[ 0.2, -0.1,  0.4,  0.0],
              [-0.3,  0.5,  0.1, -0.2],
              [ 0.1,  0.3, -0.4,  0.6]])
b = np.array([0.1, -0.2, 0.3])

# z = W @ x + b
# print(f'Salida z = {z}')
# print(f'¿Qué forma tiene z? ¿Qué representa?')

# %%
# TODO — Aplica una activación ReLU a la salida z del ejercicio anterior
# ReLU(x) = max(0, x)

# z = ... (del ejercicio anterior)
# a = np.maximum(0, z)
# print(f'Activación ReLU: {a}')

# %%
# TODO — Preguntas de reflexión
# 1. ¿Cuál es la diferencia entre IA, ML y DL?
# 2. ¿Por qué el algoritmo de backpropagation fue clave para el renacimiento de las RNA?
# 3. ¿Qué papel juega la regla de la cadena en el entrenamiento de redes neuronales?
# 4. ¿Por qué una neurona artificial necesita una función de activación?
#
# Responde en comentarios:
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# ## ✅ Resumen del Módulo 1
#
# | Tema | Función clave | Concepto principal |
# |------|---------------|--------------------|
# | Aprendizaje | `tipos_aprendizaje()` | Supervisado, No supervisado, Refuerzo |
# | Ramas de IA | `ramas_ia()` | ML, DL, NLP, Visión, Robótica |
# | Conceptos | `concepto_clave(nombre)` | Overfitting, Backpropagation, Gradiente |
# | Historia | `hitos_rna()` | 1943 McCulloch-Pitts → 2024 Multimodal |
# | Vectores | `vectores_basicos()` | Producto punto, magnitud, ángulo |
# | Matrices | `matrices_basicas()` | Producto matricial, transpuesta, inversa |
# | Derivadas | `derivada_simbolica()` | Regla de la cadena, derivada de sigmoide |
# | Funciones | `graficar_funciones()` | x², eˣ, ln(x) |
# | Diplomado | `ruta_diplomado()` | 5 módulos: IA → Python → ML → DL → TinyML |
