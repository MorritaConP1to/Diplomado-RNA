# %%
# Importamos las librerías fundamentales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# 1. Cargamos el dataset Iris
iris = load_iris()
X = iris.data # Las características (medidas de las flores)
y = iris.target # Las etiquetas (el tipo de flor real)
feature_names = iris.feature_names

# Lo convertimos a una tabla (DataFrame) para verlo mejor
df = pd.DataFrame(X, columns=feature_names)
df['especie'] = pd.Categorical.from_codes(iris.target, iris.target_names)

print("Primeras 5 filas de nuestros datos:")
display(df.head())

# -------------------------------------------------------------------
# 2. DIVISIÓN DE DATOS (¡Este era el paso que faltaba!)
# Guardamos el 70% para que el modelo estudie, y el 30% para hacerle el examen
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# -------------------------------------------------------------------
# Out:
# Primeras 5 filas de nuestros datos:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   especie
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from sklearn.cluster import KMeans

# Le pedimos que encuentre 3 grupos (porque sabemos que hay 3 especies, aunque el algoritmo no lo sabe)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters_kmeans = kmeans.fit_predict(X)

# Visualizamos el resultado usando solo dos características (Largo y Ancho del Sépalo)
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=clusters_kmeans, cmap='viridis', s=50, alpha=0.8)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', marker='X', s=200, label='Centroides (Centros de mesa)')
plt.title("Agrupamiento K-Means (Largo vs Ancho del Sépalo)")
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])
plt.legend()
plt.show()
